# %% [markdown]
# "does equipment wait time drive churn more than how often they attend?"

# %%
import pandas as pd

df = pd.read_csv("gym_churn_1M_dataset.csv")
df.head()
# Out:
#    Member_ID  Age  Gender Membership_Type Membership_Start_Date  Monthly_Fee  \
# 0          1   17    Male         Premium            2025-08-20        74.61
# 1          2   57    Male         Premium            2023-10-18        73.89
# 2          3   26  Female        Standard            2024-08-20        27.77
# 3          4   25    Male        Standard            2024-01-28        28.90
# 4          5   26    Male            Gold            2025-03-21        48.41
#
#    Monthly_Visits  Avg_Workout_Duration_Min Peak_Hour_Preference  \
# 0              10                        76      Evening (17-21)
# 1               3                        40      Evening (17-21)
# 2              12                        62   Late Night (21-24)
# 3               5                        58       Midday (10-14)
# 4              24                        40   Late Night (21-24)
#
#   Cardio_Preference  Treadmill_Avg_Speed_Kmh  Treadmill_Avg_Incline_Pct  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Member_ID                    1000000 non-null  int64
#  1   Age                          1000000 non-null  int64
#  2   Gender                       1000000 non-null  object
#  3   Membership_Type              1000000 non-null  object
#  4   Membership_Start_Date        1000000 non-null  object
#  5   Monthly_Fee                  1000000 non-null  float64
#  6   Monthly_Visits               1000000 non-null  int64
#  7   Avg_Workout_Duration_Min     1000000 non-null  int64
#  8   Peak_Hour_Preference         1000000 non-null  object
#  9   Cardio_Preference            773315 non-null   object
#  10  Treadmill_Avg_Speed_Kmh      337598 non-null   float64
#  11  Treadmill_Avg_Incline_Pct    337598 non-null   float64
# ...

# %% [markdown]
# Data Cleaning

# %% [markdown]
# 1. Diagnosis before treatment

# %%
# Check for duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check stats on the variable needed for analysis
df[["Monthly_Visits", "Avg_Equipment_Wait_Time_Min"]].describe()
# Out:
#        Monthly_Visits  Avg_Equipment_Wait_Time_Min
# count  1000000.000000               1000000.000000
# mean         9.758237                    12.086831
# std          6.760107                     7.441821
# min          0.000000                     0.000000
# 25%          4.000000                     5.600000
# 50%          9.000000                    12.100000
# 75%         13.000000                    18.500000
# max         28.000000                    25.000000
